# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#dataset=pd.read_csv(r'SalesFriday.csv')

# %%
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share your notebook.
client_554d6f53934a4ba7815f605e5d7a6f08 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='fq1FcHO3Pp_gVzzkjzmHHr489Et7y99XVpeNFffgjg5d',
    ibm_auth_endpoint="https://iam.bluemix.net/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.eu-geo.objectstorage.service.networklayer.com')

body = client_554d6f53934a4ba7815f605e5d7a6f08.get_object(Bucket='blackfriday-donotdelete-pr-vm3nxh7kpgytge',Key='SalesFriday.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )
dataset= pd.read_csv(body)
dataset.head()
# Out:
#   Gender  1ge  Occupation  Stay in Years  Marital Status  Prod_category  \
# 0      F   10          10              2               0              3
# 1      F   10          10              2               0              1
# 2      F   10          10              2               0             12
# 3      F   10          10              2               0             12
# 4      M   60          16              5               0              8
#
#    Purchase  Category
# 0      8370         1
# 1     15200         1
# 2      1422         1
# 3      1057         1
# 4      7969         0

# %%
dataset
# Out:
#        Gender  1ge  Occupation  Stay in Years  Marital Status  Prod_category  \
# 0           F   10          10              2               0              3
# 1           F   10          10              2               0              1
# 2           F   10          10              2               0             12
# 3           F   10          10              2               0             12
# 4           M   60          16              5               0              8
# 5           M   30          15              3               0              1
# 6           M   48           7              2               1              1
# 7           M   48           7              2               1              1
# 8           M   48           7              2               1              1
# 9           M   30          20              1               1              8
# 10          M   30          20              1               1              5
# ...

# %%
dataset.head()
# Out:
#   Gender  1ge  Occupation  Stay in Years  Marital Status  Prod_category  \
# 0      F   10          10              2               0              3
# 1      F   10          10              2               0              1
# 2      F   10          10              2               0             12
# 3      F   10          10              2               0             12
# 4      M   60          16              5               0              8
#
#    Purchase  Category
# 0      8370         1
# 1     15200         1
# 2      1422         1
# 3      1057         1
# 4      7969         0

# %%
dataset.tail()
# Out:
#        Gender  1ge  Occupation  Stay in Years  Marital Status  Prod_category  \
# 537572      M   40          16              1               0              1
# 537573      M   40          16              1               0              1
# 537574      M   40          16              1               0              8
# 537575      M   40          16              1               0              5
# 537576      M   40          16              1               0              5
#
#         Purchase  Category
# 537572     11664         0
# 537573     19196         0
# 537574      8043         0
# 537575      7172         0
# 537576      6875         0

# %%
dataset.isnull().any()
# Out:
# Gender            False
# 1ge               False
# Occupation        False
# Stay in Years     False
# Marital Status    False
# Prod_category     False
# Purchase          False
# Category          False
# dtype: bool

# %%
x=dataset.iloc[:,0:7].values
x
# Out:
# array([['F', 10, 10, ..., 0, 3, 8370],
#        ['F', 10, 10, ..., 0, 1, 15200],
#        ['F', 10, 10, ..., 0, 12, 1422],
#        ...,
#        ['M', 40, 16, ..., 0, 8, 8043],
#        ['M', 40, 16, ..., 0, 5, 7172],
#        ['M', 40, 16, ..., 0, 5, 6875]], dtype=object)

# %%
y=dataset.iloc[:,-1:].values
y
# Out:
# array([[1],
#        [1],
#        [1],
#        ...,
#        [0],
#        [0],
#        [0]])

# %%
from sklearn.preprocessing import LabelEncoder
lor=LabelEncoder()

# %%
x[:,0]=lor.fit_transform(x[:,0])
x
# Out:
# array([[0, 10, 10, ..., 0, 3, 8370],
#        [0, 10, 10, ..., 0, 1, 15200],
#        [0, 10, 10, ..., 0, 12, 1422],
#        ...,
#        [1, 40, 16, ..., 0, 8, 8043],
#        [1, 40, 16, ..., 0, 5, 7172],
#        [1, 40, 16, ..., 0, 5, 6875]], dtype=object)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train
# Out:
# array([[1, 30, 0, ..., 0, 8, 7837],
#        [1, 30, 2, ..., 0, 5, 8762],
#        [1, 30, 0, ..., 1, 8, 7778],
#        ...,
#        [0, 48, 15, ..., 1, 5, 6991],
#        [1, 22, 4, ..., 1, 2, 13251],
#        [1, 60, 17, ..., 0, 8, 9905]], dtype=object)

# %%
y_train
# Out:
# array([[1],
#        [1],
#        [1],
#        ...,
#        [0],
#        [1],
#        [0]])

# %%
x_test
# Out:
# array([[0, 22, 4, ..., 0, 1, 11394],
#        [1, 30, 20, ..., 1, 7, 12781],
#        [1, 53, 2, ..., 1, 6, 20068],
#        ...,
#        [0, 30, 1, ..., 0, 8, 7957],
#        [1, 30, 14, ..., 0, 5, 8770],
#        [1, 40, 14, ..., 0, 6, 20487]], dtype=object)

# %%
y_test
# Out:
# array([[1],
#        [1],
#        [1],
#        ...,
#        [1],
#        [1],
#        [0]])

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
x_train
# Out:
# array([[ 0.57015696, -0.38468554, -1.23968144, ..., -0.83107805,
#          0.7225614 , -0.30111344],
#        [ 0.57015696, -0.38468554, -0.93292539, ..., -0.83107805,
#         -0.07724542, -0.11549459],
#        [ 0.57015696, -0.38468554, -1.23968144, ...,  1.20325642,
#          0.7225614 , -0.31295291],
#        ...,
#        [-1.75390301,  1.23668492,  1.06098893, ...,  1.20325642,
#         -0.07724542, -0.47087943],
#        [ 0.57015696, -1.10529463, -0.62616934, ...,  1.20325642,
#         -0.87705224,  0.78530867],
#        [ 0.57015696,  2.31759856,  1.36774498, ..., -0.83107805,
#          0.7225614 ,  0.11387011]])

# %%
x_test
# Out:
# array([[-1.75390301, -1.10529463, -0.62616934, ..., -0.83107805,
#         -1.14365451,  0.41266629],
#        [ 0.57015696, -0.38468554,  1.82787906, ...,  1.20325642,
#          0.45595913,  0.69099423],
#        [ 0.57015696,  1.68706561, -0.93292539, ...,  1.20325642,
#          0.18935685,  2.15326942],
#        ...,
#        [-1.75390301, -0.38468554, -1.08630342, ..., -0.83107805,
#          0.7225614 , -0.27703315],
#        [ 0.57015696, -0.38468554,  0.90761091, ..., -0.83107805,
#         -0.07724542, -0.11388923],
#        [ 0.57015696,  0.51607583,  0.90761091, ..., -0.83107805,
#          0.18935685,  2.23734974]])

# %%
y_test
# Out:
# array([[1],
#        [1],
#        [1],
#        ...,
#        [1],
#        [1],
#        [0]])

# %%
from sklearn.tree import DecisionTreeClassifier
classifier=DecisionTreeClassifier(criterion="gini",random_state=0)

# %%
classifier.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=0,
#             splitter='best')

# %%
y_predict=classifier.predict(x_test)
y_predict
# Out:
# array([1, 1, 0, ..., 1, 0, 1])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_predict)
# Out:
# 0.7336675471557722

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_predict)
cm
# Out:
# array([[19295, 13707],
#        [14928, 59586]])

# %%
import sklearn.metrics as metrics
fpr,tpr,threshold=metrics.roc_curve(y_test,y_predict)
roc_auc=metrics.auc(fpr,tpr)
roc_auc
# Out:
# 0.69216167209185486

# %%
plt.title("ROC")
plt.plot(fpr,tpr,label="AUC=%0.2f"%roc_auc,color="red")
plt.xlabel("FPR")
plt.ylabel("TPR")
plt.legend()
plt.show()

# %%
# !pip install watson-machine-learning-client --upgrade
# Out:
# Requirement already up-to-date: watson-machine-learning-client in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (1.0.365)
# Requirement not upgraded as not directly required: tqdm in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from watson-machine-learning-client) (4.19.5)
# Requirement not upgraded as not directly required: requests in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from watson-machine-learning-client) (2.18.4)
# Requirement not upgraded as not directly required: ibm-cos-sdk in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from watson-machine-learning-client) (2.0.1)
# Requirement not upgraded as not directly required: tabulate in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from watson-machine-learning-client) (0.8.2)
# Requirement not upgraded as not directly required: pandas in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from watson-machine-learning-client) (0.21.0)
# ...

# %%
from watson_machine_learning_client import WatsonMachineLearningAPIClient
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# 2019-05-22 10:44:17,943 - watson_machine_learning_client.metanames - WARNING - 'AUTHOR_EMAIL' meta prop is deprecated. It will be ignored.
# 2019-05-22 10:44:37,850 - watson_machine_learning_client.wml_client_error - WARNING - Deployment creation failed. Error: 402. {"trace":"e3eb5d52edb5bd55469b79fe7c599fcc","errors":[{"code":"deployments_plan_limit_reached","message":"Current plan 'lite' only allows 5 deployments"}]}
# ...

# %%
wml_credentials={
  "access_key": "B8PcPYeADfAOHpT2wyb3PeAPVtOocJCXFaHTW2k2S8zo",  
  "instance_id": "e73fb861-6de6-4260-9ff9-e55370c99f53",
  "password": "49e47333-1973-4941-9688-18d92fad6125",
  "url": "https://eu-gb.ml.cloud.ibm.com",
  "username": "9d7b8a1d-821a-4649-8c5a-fe4a90bc33c5"
}

# %%
client = WatsonMachineLearningAPIClient(wml_credentials)
import json

# %%
instance_details = client.service_instance.get_details()
print(json.dumps(instance_details, indent=2))
# Out:
# {
#   "metadata": {
#     "url": "https://eu-gb.ml.cloud.ibm.com/v3/wml_instances/e73fb861-6de6-4260-9ff9-e55370c99f53",
#     "modified_at": "2019-05-22T08:56:48.327Z",
#     "created_at": "2019-05-14T08:23:08.152Z",
#     "guid": "e73fb861-6de6-4260-9ff9-e55370c99f53"
#   },
#   "entity": {
#     "usage": {
#       "deployment_count": {
#         "current": 2,
#         "limit": 5
#       },
#       "computation_time": {
#         "current": 0,
#         "limit": 180000
#       },
#       "gpu_count_k80": {
#         "current": 0,
#         "limit": 8
#       },
#       "prediction_count": {
#         "current": 5,
#         "limit": 5000
#       },
#       "model_count": {
#         "current": 6,
#         "limit": 200
#       },
#       "expiration_date": "2019-06-01T00:00:00.000Z",
#       "gpu_count_p100": {
#         "current": 0,
#         "limit": 0
#       },
#       "gpu_count_v100": {
#         "current": 0,
#         "limit": 0
#       },
#       "capacity_units": {
# ...

# %%
model_props = {client.repository.ModelMetaNames.AUTHOR_NAME: "Lakshmi Sirisha Yadav Peruboina", 
               client.repository.ModelMetaNames.AUTHOR_EMAIL: "lakshmisirishap442@gmail.com", 
               client.repository.ModelMetaNames.NAME: "Random"}

# %%
model_artifact =client.repository.store_model(classifier, meta_props=model_props)

# %%
published_model_uid = client.repository.get_model_uid(model_artifact)

# %%
published_model_uid
# Out:
# 'fc6468e2-93c4-4144-9c9f-ff4e37671eea'

# %%
client.deployments.list()
# Out:
# ------------------------------------  -----------  ------  --------------  ------------------------  -----------------  -------------
# GUID                                  NAME         TYPE    STATE           CREATED                   FRAMEWORK          ARTIFACT TYPE
# 7ee78f38-9aba-43d2-aec7-262a27eb370f  blackfriday  online  DEPLOY_SUCCESS  2019-05-22T10:45:05.785Z  scikit-learn-0.19  model
# 26dd70d5-f37f-40c7-92c7-0598a2ac3b82  blackfriday  online  DEPLOY_SUCCESS  2019-05-22T09:15:45.362Z  scikit-learn-0.19  model
# 66999d78-6aba-4ddb-830d-635492a5680e  multilinear  online  DEPLOY_SUCCESS  2019-05-21T14:04:19.749Z  scikit-learn-0.19  model
# 720dd80a-5fd9-4ae7-868b-10cceaa113db  multilinear  online  DEPLOY_SUCCESS  2019-05-18T05:16:58.928Z  scikit-learn-0.19  model
# f094d857-073c-4949-8b63-5af4a4ed3b65  multilinear  online  DEPLOY_SUCCESS  2019-05-18T04:21:05.583Z  scikit-learn-0.19  model
# ...

# %%
client.deployments.delete('f094d857-073c-4949-8b63-5af4a4ed3b65')
# Out:
# 'SUCCESS'

# %%
created_deployment = client.deployments.create(published_model_uid, name="blackfriday")
# Out:
# #######################################################################################
#
# Synchronous deployment creation for uid: 'fc6468e2-93c4-4144-9c9f-ff4e37671eea' started
#
# #######################################################################################
#
#
# INITIALIZING
# DEPLOY_SUCCESS
#
#
# ------------------------------------------------------------------------------------------------
# Successfully finished deployment creation, deployment_uid='8e0188af-8da0-4703-8ee3-8f96b64ae048'
# ------------------------------------------------------------------------------------------------

# %%
scoring_endpoint = client.deployments.get_scoring_url(created_deployment)
scoring_endpoint
# Out:
# 'https://eu-gb.ml.cloud.ibm.com/v3/wml_instances/e73fb861-6de6-4260-9ff9-e55370c99f53/deployments/8e0188af-8da0-4703-8ee3-8f96b64ae048/online'

# %%
client.deployments.list()
# Out:
# ------------------------------------  -----------  ------  --------------  ------------------------  -----------------  -------------
# GUID                                  NAME         TYPE    STATE           CREATED                   FRAMEWORK          ARTIFACT TYPE
# 7ee78f38-9aba-43d2-aec7-262a27eb370f  blackfriday  online  DEPLOY_SUCCESS  2019-05-22T10:45:05.785Z  scikit-learn-0.19  model
# 26dd70d5-f37f-40c7-92c7-0598a2ac3b82  blackfriday  online  DEPLOY_SUCCESS  2019-05-22T09:15:45.362Z  scikit-learn-0.19  model
# 66999d78-6aba-4ddb-830d-635492a5680e  multilinear  online  DEPLOY_SUCCESS  2019-05-21T14:04:19.749Z  scikit-learn-0.19  model
# 720dd80a-5fd9-4ae7-868b-10cceaa113db  multilinear  online  DEPLOY_SUCCESS  2019-05-18T05:16:58.928Z  scikit-learn-0.19  model
# f094d857-073c-4949-8b63-5af4a4ed3b65  multilinear  online  DEPLOY_SUCCESS  2019-05-18T04:21:05.583Z  scikit-learn-0.19  model
# ...
